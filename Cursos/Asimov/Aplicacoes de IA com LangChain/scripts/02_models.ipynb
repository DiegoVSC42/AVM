# %% [markdown]
# # Models

# %% [markdown]
# ## LLMs

# %% [markdown]
# Modelos de Linguagem Grande (LLMs, na sigla em inglês) são um componente central do LangChain. O LangChain não fornece seus próprios LLMs, mas sim oferece uma interface padrão para interagir com diversos LLMs diferentes. Para ser específico, essa interface é uma que recebe como entrada uma string e retorna uma string.
#
# Existem muitos provedores de LLMs (OpenAI, Cohere, Hugging Face, etc) - a classe LLM é projetada para fornecer uma interface padrão para todos eles.

# %%
pip install -r requirements.txt
# Out:
# Ignoring audioop-lts: markers 'python_version >= "3.13"' don't match your environment
# Requirement already satisfied: langchain==0.3.13 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 2)) (0.3.13)
# Requirement already satisfied: langchain-core==0.3.56 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 3)) (0.3.56)
# Requirement already satisfied: langchain-openai==0.2.13 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: langchain-community==0.3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: langchain-huggingface==0.1.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: langchain-chroma==0.1.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: transformers==4.47.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 10)) (4.47.1)
# Requirement already satisfied: huggingface_hub==0.27.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 11)) (0.27.0)
# Requirement already satisfied: sentence-transformers==3.3.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 12)) (3.3.1)
# Requirement already satisfied: pydantic==2.7.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 15)) (2.7.4)
# Requirement already satisfied: openai==1.55.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 18)) (1.55.3)
# Requirement already satisfied: ipykernel in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 21)) (7.1.0)
# Requirement already satisfied: jinja2==3.1.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 22)) (3.1.4)
# Requirement already satisfied: pypdf==5.1.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 23)) (5.1.0)
# Requirement already satisfied: yt_dlp in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 24)) (2025.12.8)
# Requirement already satisfied: pydub in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 25)) (0.25.1)
# Requirement already satisfied: beautifulsoup4==4.12.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 27)) (4.12.3)
# Requirement already satisfied: faiss-cpu==1.9.0.post1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 28)) (1.9.0.post1)
# Requirement already satisfied: lark==1.2.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from -r requirements.txt (line 29)) (1.2.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain==0.3.13->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-core==0.3.56->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-core==0.3.56->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-core==0.3.56->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from pydantic==2.7.4->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from pydantic==2.7.4->-r requirements.txt (line 15)) (2.18.4)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-openai==0.2.13->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from openai==1.55.3->-r requirements.txt (line 18)) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from openai==1.55.3->-r requirements.txt (line 18)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from openai==1.55.3->-r requirements.txt (line 18)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from openai==1.55.3->-r requirements.txt (line 18)) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from openai==1.55.3->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from openai==1.55.3->-r requirements.txt (line 18)) (4.67.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-community==0.3.0->-r requirements.txt (line 5)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-community==0.3.0->-r requirements.txt (line 5)) (2.12.0)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-huggingface==0.1.2->-r requirements.txt (line 6)) (0.21.4)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.5.20)
# Requirement already satisfied: fastapi<1,>=0.95.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.127.0)
# Requirement already satisfied: filelock in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from transformers==4.47.1->-r requirements.txt (line 10)) (3.20.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from transformers==4.47.1->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from transformers==4.47.1->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from huggingface_hub==0.27.0->-r requirements.txt (line 11)) (2025.12.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from sentence-transformers==3.3.1->-r requirements.txt (line 12)) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from sentence-transformers==3.3.1->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: scipy in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from sentence-transformers==3.3.1->-r requirements.txt (line 12)) (1.16.3)
# Requirement already satisfied: Pillow in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from sentence-transformers==3.3.1->-r requirements.txt (line 12)) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from jinja2==3.1.4->-r requirements.txt (line 22)) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from beautifulsoup4==4.12.3->-r requirements.txt (line 27)) (2.8.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.13->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: idna>=2.8 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai==1.55.3->-r requirements.txt (line 18)) (3.11)
# Requirement already satisfied: build>=1.0.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.40.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (7.4.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.39.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.20.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (3.11.5)
# Requirement already satisfied: rich>=10.11.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (14.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.0->-r requirements.txt (line 5)) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.0->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: certifi in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai==1.55.3->-r requirements.txt (line 18)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai==1.55.3->-r requirements.txt (line 18)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.55.3->-r requirements.txt (line 18)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.56->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.13->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.0->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.0->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from requests<3,>=2->langchain==0.3.13->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from requests<3,>=2->langchain==0.3.13->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.13->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.0->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (9.8.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 21)) (5.14.3)
# Requirement already satisfied: pyproject_hooks in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: colorama in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from jupyter-client>=8.0.0->ipykernel->-r requirements.txt (line 21)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 21)) (4.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (6.33.2)
# Requirement already satisfied: sympy in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.60b1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.60b1)
# Requirement already satisfied: opentelemetry-util-http==0.60b1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.17.3)
# Requirement already satisfied: asgiref~=3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.60b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (3.11.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 21)) (0.2.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.3.1->-r requirements.txt (line 12)) (3.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma==0.1.4->-r requirements.txt (line 7)) (3.3.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from scikit-learn->sentence-transformers==3.3.1->-r requirements.txt (line 12)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from scikit-learn->sentence-transformers==3.3.1->-r requirements.txt (line 12)) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain_google_genai
# Out:
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-4.1.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain_google_genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain_google_genai)
#   Downloading google_genai-1.56.0-py3-none-any.whl.metadata (53 kB)
# Collecting langchain-core<2.0.0,>=1.2.2 (from langchain_google_genai)
#   Downloading langchain_core-1.2.4-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain_google_genai) (2.7.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.45.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.45.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.0.0 (from langchain_google_genai)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai)
#   Downloading langsmith-0.5.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (6.0.3)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai)
#   Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (1.0.0)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain_google_genai)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.0.0->langchain_google_genai)
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\diego\onedrive\documentos\git\avm\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.6.1)
# Downloading langchain_google_genai-4.1.2-py3-none-any.whl (65 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.56.0-py3-none-any.whl (426 kB)
# Downloading langchain_core-1.2.4-py3-none-any.whl (477 kB)
# Downloading langsmith-0.5.0-py3-none-any.whl (273 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 18.8 MB/s  0:00:00
# Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Installing collected packages: filetype, zstandard, uuid-utils, pydantic-core, pydantic, langsmith, langchain-core, google-genai, langchain_google_genai
#
#    ---------------------------------------- 0/9 [filetype]
#    ---------------------------------------- 0/9 [filetype]
#    ---- ----------------------------------- 1/9 [zstandard]
#   Attempting uninstall: pydantic-core
#    ---- ----------------------------------- 1/9 [zstandard]
#     Found existing installation: pydantic_core 2.18.4
#    ---- ----------------------------------- 1/9 [zstandard]
#     Uninstalling pydantic_core-2.18.4:
#    ---- ----------------------------------- 1/9 [zstandard]
#       Successfully uninstalled pydantic_core-2.18.4
#    ---- ----------------------------------- 1/9 [zstandard]
#    ------------- -------------------------- 3/9 [pydantic-core]
#    ------------- -------------------------- 3/9 [pydantic-core]
#   Attempting uninstall: pydantic
#    ------------- -------------------------- 3/9 [pydantic-core]
#     Found existing installation: pydantic 2.7.4
#    ------------- -------------------------- 3/9 [pydantic-core]
#     Uninstalling pydantic-2.7.4:
#    ------------- -------------------------- 3/9 [pydantic-core]
#       Successfully uninstalled pydantic-2.7.4
#    ------------- -------------------------- 3/9 [pydantic-core]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#    ----------------- ---------------------- 4/9 [pydantic]
#   Attempting uninstall: langsmith
#    ----------------- ---------------------- 4/9 [pydantic]
#     Found existing installation: langsmith 0.1.147
#    ----------------- ---------------------- 4/9 [pydantic]
#     Uninstalling langsmith-0.1.147:
#    ----------------- ---------------------- 4/9 [pydantic]
#       Successfully uninstalled langsmith-0.1.147
#    ----------------- ---------------------- 4/9 [pydantic]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#    ---------------------- ----------------- 5/9 [langsmith]
#   Attempting uninstall: langchain-core
#    ---------------------- ----------------- 5/9 [langsmith]
#     Found existing installation: langchain-core 0.3.56
#    ---------------------- ----------------- 5/9 [langsmith]
#     Uninstalling langchain-core-0.3.56:
#    ---------------------- ----------------- 5/9 [langsmith]
#       Successfully uninstalled langchain-core-0.3.56
#    ---------------------- ----------------- 5/9 [langsmith]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    -------------------------- ------------- 6/9 [langchain-core]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ----------------------------------- ---- 8/9 [langchain_google_genai]
#    ---------------------------------------- 9/9 [langchain_google_genai]
#
# Successfully installed filetype-1.2.0 google-genai-1.56.0 langchain-core-1.2.4 langchain_google_genai-4.1.2 langsmith-0.5.0 pydantic-2.12.5 pydantic-core-2.41.5 uuid-utils-0.12.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.13 requires langchain-core<0.4.0,>=0.3.26, but you have langchain-core 1.2.4 which is incompatible.
# langchain 0.3.13 requires langsmith<0.3,>=0.1.17, but you have langsmith 0.5.0 which is incompatible.
# langchain-chroma 0.1.4 requires langchain-core<0.4,>=0.1.40; python_version >= "3.9", but you have langchain-core 1.2.4 which is incompatible.
# langchain-community 0.3.0 requires langchain-core<0.4.0,>=0.3.0, but you have langchain-core 1.2.4 which is incompatible.
# langchain-community 0.3.0 requires langsmith<0.2.0,>=0.1.112, but you have langsmith 0.5.0 which is incompatible.
# langchain-huggingface 0.1.2 requires langchain-core<0.4.0,>=0.3.15, but you have langchain-core 1.2.4 which is incompatible.
# langchain-openai 0.2.13 requires langchain-core<0.4.0,>=0.3.27, but you have langchain-core 1.2.4 which is incompatible.
# langchain-text-splitters 0.3.8 requires langchain-core<1.0.0,>=0.3.51, but you have langchain-core 1.2.4 which is incompatible.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

api_key = os.getenv("GEMINI_API_KEY")
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %% [markdown]
# ### Chamando a llm

# %%
pergunta = 'Conte uma história breve sobre a jornada de aprender a programar'
resposta = llm.invoke(pergunta)
print(resposta.content)
# Out:
# A jornada de aprender a programar, para mim, começou com um misto de fascinação e pavor. Era como olhar para um idioma alienígena, cheio de palavras desconhecidas e uma gramática que parecia desafiar a lógica. Minha primeira incursão foi com o HTML, pensando ser algo simples, como construir uma página web básica. Eu me sentia como um arquiteto digital, arrastando e soltando elementos, mas rapidamente percebi que por trás da "construção" havia uma linguagem específica a ser compreendida.
#
# A tela em branco e os primeiros símbolos crípticos – `<html>`, `<head>`, `<body>` – eram intimidadoramente abstratos. Lembro-me de passar horas tentando entender por que um link não funcionava ou por que uma imagem insistia em não aparecer. Era um ciclo de frustração e pequenas vitórias. Cada erro era uma lição dolorosa, mas cada vez que algo *finalmente* funcionava, era como acender uma pequena luz no escuro.
#
# Então veio o JavaScript. Isso foi um salto quântico. De repente, eu não estava apenas organizando elementos, mas dando vida a eles. A ideia de que o computador pudesse *fazer* coisas por conta própria, com base nas minhas instruções, era revolucionária. Mas o JavaScript era um monstro diferente. Variáveis, funções, loops – o vocabulário se expandiu exponencialmente.
#
# Houve momentos de desânimo. Noites em que a cabeça latejava, o código parecia embaçado e a sensação de estar estagnado era avassaladora. Eu me perguntava se eu tinha o "dom" para isso, se meu cérebro simplesmente não era feito para pensar de forma tão lógica e sequencial. Via amigos absorvendo conceitos com facilidade, enquanto eu lutava com as nuances de um ponto e vírgula.
#
# Mas a curiosidade era mais forte. A ideia de criar algo do zero, de transformar pensamentos em ações executáveis, me impulsionava. Comecei a procurar tutoriais, vídeos, fóruns. Cada resposta que encontrava, cada pedacinho de código que entendia, era como encontrar um mapa em um território desconhecido. Eu aprendi a amar a busca pela solução, a satisfação de "desenrolar" um problema complexo em partes menores e mais manejáveis.
#
# A mudança mais significativa foi quando comecei a pensar como um programador. A forma como eu olhava para o mundo mudou. Comecei a notar padrões, a questionar a eficiência de processos e a pensar em como poderiam ser automatizados. De repente, um problema cotidiano podia ser visto como um desafio de programação a ser resolvido.
#
# A jornada está longe de terminar. A tecnologia evolui a um ritmo vertiginoso, e sempre há algo novo para aprender. Mas agora, o medo deu lugar a um respeito saudável pela complexidade e uma profunda admiração pela capacidade humana de criar ferramentas tão poderosas. A programação não é mais um idioma alienígena, mas um diálogo, uma conversa com a máquina que, a cada linha escrita, se torna mais fluida e cheia de possibilidades. E essa jornada de descoberta contínua é, em si, uma das recompensas mais gratificantes.

# %% [markdown]
# ### Chamando com stream de resposta

# %%
pergunta = 'Conte uma história breve sobre a jornada de aprender a programar'
for trecho in llm.stream(pergunta):
    print(trecho, end='')
# Out:
# content='## A Dan' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 13, 'output_tokens': 3, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}}content='ça dos Pixels: Uma Jornada no Mundo da Programação\n\nEra uma' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 16, 'output_tokens': 16}content=' vez, num reino de telas brilhantes e códigos misteriosos, um jovem chamado Alex. Alex não era um príncipe nem um guerreiro destemido, mas um sonhador com uma curiosidade insaciável. Um dia, enquanto naveg' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 49, 'output_tokens': 49}content='ava pelas maravilhas da internet, ele se deparou com um portal: a programação.\n\nO portal era um labirinto de símbolos estranhos, palavras como "Python", "HTML" e "JavaScript" flutuavam como criaturas' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 50, 'output_tokens': 50}content=' exóticas. Intrigado, Alex deu o primeiro passo. Seu primeiro programa foi um singelo "Olá, Mundo!" – uma frase tão simples, mas que ressoou como um eco de conquista em sua mente. Era a' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 48, 'output_tokens': 48}content=' primeira vez que ele via suas palavras ganharem vida, dançando nos pixels da tela.\n\nA jornada, porém, não foi um caminho florido. Houve momentos de frustração, onde os erros se acumulavam como nuvens de tempestade.' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 52, 'output_tokens': 52}content=' Linhas e linhas de código pareciam zombar dele, com pontos e vírgulas fora do lugar, colchetes mal fechados. Alex se sentia como um alquimista que não conseguia encontrar a fórmula certa para sua' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 48, 'output_tokens': 48}content=' poção.\n\nHouve noites em claro, alimentado por café e a determinação de desvendar os enigmas que o código apresentava. Ele lia tutoriais que pareciam escritos em outra língua, participava de fóruns onde' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 51, 'output_tokens': 51}content=' as respostas eram tão enigmáticas quanto as perguntas. Mas a cada erro corrigido, a cada pequeno sucesso, uma faísca de confiança se acendia.\n\nEle aprendeu a dançar com os loops, a criar estruturas com as condicion' additional_kwargs={} response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b471b-96eb-7ff3-9924-05d32dc35d2a' usage_metadata={'input_tokens': 0, 'input_token_details': {'cache_read': 0}, 'total_tokens': 51, 'output_tokens': 51}content='ais, a construir mundos com as  ...

# %% [markdown]
# ### Chamadas simultâneas

# %%
perguntas = [
    'O que é o céu?',
    'O que é a terra?',
    'O que são as estrelas?'
]

llm.batch(perguntas)
# Out:
# [AIMessage(content='A pergunta "o que é o céu?" é fascinante porque pode ter diferentes interpretações dependendo do contexto. Vamos explorar as principais:\n\n**1. O Céu na Astronomia e Meteorologia (o que vemos acima de nós):**\n\n* **Atmosfera da Terra:** Na visão mais comum e cotidiana, o céu é a **atmosfera da Terra**. É a camada de gases que envolve nosso planeta e que vemos quando olhamos para cima.\n    * **Durante o dia:** A luz do Sol é espalhada pelas moléculas de ar (principalmente nitrogênio e oxigênio), o que faz com que o céu pareça azul. O fenômeno é conhecido como **espalhamento de Rayleigh**.\n    * **Ao amanhecer e entardecer:** A luz do Sol precisa atravessar uma camada maior da atmosfera, e as cores de comprimento de onda mais longo (vermelho, laranja, amarelo) são menos espalhadas, tornando o céu nessas horas com tons avermelhados e alaranjados.\n    * **Nuvens:** As nuvens são formadas por gotículas de água ou cristais de gelo suspensos na atmosfera, e sua aparência (branca, cinza, escura) depende da quantidade de luz que elas refletem ou absorvem.\n    * **Clima:** O céu está intrinsecamente ligado ao clima, com fenômenos como chuva, neve, raios, arco-íris, etc., ocorrendo em nosso céu.\n\n* **Espaço Sideral:** Em um sentido mais amplo, "céu" também pode se referir ao **espaço sideral**, o vasto vácuo que existe além da atmosfera da Terra. É onde encontramos:\n    * **Estrelas:** O Sol é uma estrela, e os pontos luminosos que vemos à noite são outras estrelas.\n    * **Planetas:** A Terra é um planeta, e outros planetas do nosso sistema solar também são visíveis no céu noturno.\n    * **Lua:** O satélite natural da Terra.\n    * **Galáxias:** Agrupamentos massivos de estrelas, como a Via Láctea (a nossa galáxia).\n    * **Nebulosas:** Nuvens de gás e poeira no espaço.\n    * **Outros corpos celestes:** Asteroides, cometas, buracos negros, etc.\n\n**2. O Céu em Contextos Religiosos e Espirituais:**\n\n* **Morada Divina:** Em muitas religiões e crenças espirituais, o céu é concebido como um **reino sagrado, a morada de Deus, deuses, anjos ou de seres divinos**. É frequentemente descrito como um lugar de paz, felicidade eterna, recompensa para os justos e ausência de sofrimento.\n    * **Cristianismo:** O céu é o lugar para onde os fiéis vão após a morte, para estar com Deus.\n    * **Islamismo:** O Jannah (paraíso) é um lugar de prazeres celestiais para os devotos.\n    * **Judaísmo:** A concepção do além pode variar, mas muitas vezes envolve um estado de união com Deus.\n    * **Outras Religiões:** Diversas outras tradições religiosas têm suas próprias visões de um reino celestial.\n\n* **Estado de Consciência:** Em algumas filosofias e práticas espirituais, o "céu" pode ser interpretado como um **estado de profunda paz interior, iluminação espiritual ou êxtase**. Não necessariamente um lugar físico, mas uma experiência interna de bem-aventurança.\n\n**3. O Céu em Metáforas e Expressões:**\n\n* **Limites:** "O céu é o limite" significa que não há barreiras para o que se pode alcançar.\n* **Felicidade:** "Estar no céu" descreve uma sensação de imensa alegria e contentamento.\n* **Beleza:** Podemos nos referir a uma paisagem deslumbrante como um "pedacinho do céu".\n\n**Em resumo, a resposta para "o que é o céu?" depende da sua perspectiva:**\n\n* **Científica:** É a atmosfera da Terra e o espaço sideral.\n* **Religiosa/Espiritual:** É um reino divino ou um estado de consciência elevada.\n* **Figurativa:** É um símbolo de limites, felicidade ou beleza.\n\nÉ importante considerar qual dessas definições você está buscando para obter a resposta mais adequada.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b471b-ca23-7f91-b33d-02cd0b5905df-0', usage_metadata={'input_tokens': 7, 'output_tokens': 958, 'total_tokens': 965, 'input_token_details': {'cache_read': 0}}),
#  AIMessage(content='A "Terra" pode ser definida de diversas maneiras, dependendo do contexto:\n\n**1. Em termos geológicos e astronômicos:**\n\n* **Planeta:** A Terra é o **terceiro planeta do Sistema Solar em ordem de distância do Sol**. É o planeta rochoso (terrestre) mais denso e o quinto maior em diâmetro entre os oito planetas do nosso sistema.\n* **Corpo celeste:** É um corpo celeste que orbita o Sol, possui massa suficiente para que sua própria gravidade o torne aproximadamente esférico e limpou a vizinhança de sua órbita de outros corpos significativos.\n* **Lar da vida:** A Terra é o **único planeta conhecido no universo que abriga vida**, incluindo a humanidade. Essa característica é fundamental e a torna especial.\n* **Composição:** É um planeta dinâmico, composto por diferentes camadas: **núcleo** (interno e externo), **manto** e **crosta**. A superfície é dominada por oceanos (cerca de 71%) e continentes.\n* **Atmosfera:** Possui uma **atmosfera** composta principalmente por nitrogênio (cerca de 78%) e oxigênio (cerca de 21%), além de outros gases em menor quantidade. Essa atmosfera protege a vida na Terra de radiação nociva e regula a temperatura.\n* **Movimentos:** A Terra realiza dois movimentos principais:\n    * **Rotação:** Gira em torno de seu próprio eixo, causando o dia e a noite.\n    * **Translação:** Orbita o Sol, levando aproximadamente 365,25 dias para completar uma volta, o que define o ano e as estações do ano.\n\n**2. Em termos mais gerais e cotidianos:**\n\n* **Solo/Chão:** Frequentemente, "terra" se refere à **superfície sólida do planeta**, ao solo onde vivemos, plantamos, construímos, etc. Pode ser terra cultivável, terra firme, etc.\n* **País/Nação:** Em um sentido mais amplo, "terra" pode ser usado para se referir a um **território nacional**, uma pátria. Por exemplo, "defender a terra".\n* **Matéria/Substância:** Pode se referir a um **material inorgânico** que compõe o solo, rochas, argila, etc.\n\n**Em resumo, a Terra é:**\n\n* **Astronomicamente:** Um planeta rochoso único em nosso Sistema Solar, com condições propícias para a vida.\n* **Geologicamente:** Um corpo com uma estrutura interna complexa e uma superfície dinâmica.\n* **Biologicamente:** O único lar conhecido para a vida no universo.\n* **Cotidianamente:** O solo, o chão, a pátria, a matéria.\n\nA pergunta é aberta e a resposta pode ser direcionada para o aspecto que mais lhe interessa! Se tiver um contexto específico em mente, me diga!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b471b-ca25-7dd2-beda-7c87bcedd367-0', usage_metadata={'input_tokens': 7, 'output_tokens': 635, 'total_tokens': 642, 'input_token_details': {'cache_read': 0}}),
#  AIMessage(content='As estrelas são **gigantes esferas de plasma incandescente**, compostas principalmente de hidrogênio e hélio, que produzem sua própria luz e calor através de um processo chamado **fusão nuclear** em seus núcleos.\n\nVamos detalhar o que isso significa:\n\n*   **Plasma:** Em termos simples, plasma é um estado da matéria semelhante a um gás, mas onde os átomos foram ionizados. Isso significa que os elétrons foram arrancados dos núcleos atômicos, criando uma mistura de íons (átomos carregados positivamente) e elétrons livres (carregados negativamente). É um estado extremamente quente.\n\n*   **Hidrogênio e Hélio:** Estes são os elementos mais abundantes no universo e são os "combustíveis" das estrelas.\n\n*   **Fusão Nuclear:** Este é o coração da existência estelar. Nas profundezas extremas de uma estrela, onde a pressão e a temperatura são imensas, átomos de hidrogênio colidem com tanta força que se fundem para formar átomos de hélio. Durante esse processo de fusão, uma pequena quantidade de massa é convertida em uma enorme quantidade de energia, de acordo com a famosa equação de Einstein, E=mc². Essa energia é liberada na forma de luz e calor, que é o que vemos quando olhamos para as estrelas.\n\n**Em resumo, as estrelas são fornalhas cósmicas gigantes que sustentam sua existência através da fusão nuclear, convertendo elementos leves em elementos mais pesados e liberando energia em quantidades astronômicas.**\n\n**Alguns pontos importantes sobre as estrelas:**\n\n*   **Nossas prisioneiras:** O Sol é a estrela mais próxima de nós e é crucial para a vida na Terra.\n*   **Diversidade:** As estrelas vêm em uma variedade incrível de tamanhos, cores, temperaturas e luminosidades. Elas podem ser pequenas e frias (anãs vermelhas) ou gigantes e quentes (supergigantes azuis).\n*   **Ciclo de vida:** As estrelas não são eternas. Elas nascem em nebulosas (nuvens de gás e poeira), vivem por bilhões de anos (dependendo do seu tamanho) e morrem de diferentes maneiras, dependendo da sua massa. As mortes podem ser relativamente pacíficas (tornando-se anãs brancas) ou explosivas (supernovas).\n*   **Formação de elementos:** A fusão nuclear nas estrelas é responsável pela criação de muitos dos elementos químicos que conhecemos, como o oxigênio, o carbono e o ferro. Elementos mais pesados são criados em eventos mais violentos, como supernovas.\n*   **Aparência no céu:** As estrelas que vemos à noite parecem pequenos pontos de luz devido à vasta distância que nos separa delas. A cor de uma estrela nos dá uma pista sobre sua temperatura: estrelas mais frias tendem a ser avermelhadas, enquanto as mais quentes são azuis.\n\nAs estrelas são objetos fundamentais na astronomia e desempenham um papel crucial na evolução do universo, fornecendo a energia e os elementos necessários para a formação de planetas e, possivelmente, da vida.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b471b-ca26-7020-adb5-4a1b8d14200a-0', usage_metadata={'input_tokens': 8, 'output_tokens': 691, 'total_tokens': 699, 'input_token_details': {'cache_read': 0}})]

# %% [markdown]
# ## ChatModels

# %% [markdown]
# ChatModels são um componente central do LangChain.
#
# Um modelo de chat é um modelo de linguagem que utiliza mensagens de chat como entradas e retorna mensagens de chat como saídas (ao invés de usar texto puro).
#
# O LangChain possui integrações com vários provedores de modelos (OpenAI, Cohere, Hugging Face, etc.) e expõe uma interface padrão para interagir com todos esses modelos.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

chat = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

mensagens = [
    SystemMessage(content='Você é um assistente que conta piadas.'),
    HumanMessage(content='Quanto é 1 + 1?')
]
resposta = chat.invoke(mensagens)

# %%
print(resposta.content)
# Out:
# 1 + 1 é igual a... um casal de pombinhos se apaixonando! 😉

# %%
resposta.response_metadata
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash-lite',
#  'safety_ratings': [],
#  'model_provider': 'google_genai'}

# %%
from langchain_core.messages import HumanMessage, SystemMessage

mensagens = [
    SystemMessage(content='Você é um assistente que conta piadas.'),
    HumanMessage(content='Quanto é 1 + 1?')
]
for trecho in chat.stream(mensagens):
    print(trecho.content, end='')
# Out:
# 1 + 1 é 2.
#
# Agora, quer ouvir uma piada sobre isso?
#
# Por que o matemático levou uma escada para a escola?
#
# Porque ele queria chegar ao **alto nível** de conhecimento! 😄

# %% [markdown]
# Existem 5 tipos diferentes de mensagens:
#
# - `HumanMessage`: Isso representa uma mensagem do usuário. Geralmente consiste apenas de conteúdo.
#
# - `AIMessage`: Isso representa uma mensagem do modelo. Pode ter additional_kwargs incluídos - por exemplo, tool_calls se estiver usando chamadas de ferramentas da OpenAI.
#
# - `SystemMessage`: Isso representa uma mensagem do sistema, que indica ao modelo como se comportar. Geralmente consiste apenas de conteúdo. Nem todo modelo suporta isso.
#
# - `FunctionMessage`: Isso representa o resultado de uma chamada de função. Além do papel e conteúdo, esta mensagem tem um parâmetro de nome que transmite o nome da função que foi chamada para produzir este resultado.
#
# - `ToolMessage`: Isso representa o resultado de uma chamada de ferramenta. Isso é distinto de uma Mensagem de Função a fim de corresponder aos tipos de mensagens de função e ferramenta da OpenAI. Além do papel e conteúdo, esta mensagem tem um parâmetro tool_call_id que transmite o id da chamada à ferramenta que foi feita para produzir este resultado.
